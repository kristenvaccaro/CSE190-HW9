# %% [markdown]
# # Privacy on Canvas
#
# ---
#
#
# In this assignment you will consider privacy-utility tradeoffs, in both datasets and system design.
#
# ---

# %% [markdown]
# ### Part 1 - Deanonymization
#
# In Part 1, you will explore the risks of anonymizing data. The task simulates real-world scenarios where datasets with overlapping attributes can be linked to reveal private information.
#
# You are provided with:
#
#     Dataset1: Contains fields such as First Name, Last Name, Age, Location, Birth Gender, and Highest Education.
#
#     Dataset2: Contains fields such as Age, Location, Birth Gender, and Disease.
#
# #### Question 1.1: Write code to match individuals in the non-anonymous dataset with records in the anonymous dataset. [4 pt]

# %%
# Load the datasets
import pandas as pd

named_data = pd.read_csv('Dataset1.csv')
anonymous_data = pd.read_csv('Dataset2.csv')

# Display dataset information
print("Named Dataset:")
display(named_data.head())
print("\nAnonymous Dataset:")
display(anonymous_data.head())

# Write code to match a person from the named dataset with the anonymous dataset
# recommended arguments
# 1. personToMatch - a single row from the named dataset
# 2. anonymousData - the full anonymous dataset

def matchPerson(personToMatch,anonymousData):
    """
    Match a person from the non-anonymous dataset with records in the anonymous dataset.
    Should return:
        pd.DataFrame: Matching rows from the anonymous dataset.
    """

# %% [markdown]
# #### Question 1.2: What disease does Alisha Lee have? (2pt)

# %% [markdown]
# #### Question 1.3: Can we determine Timothy Ross's disease? If not, what are the possible diseases? (2pt)

# %% [markdown]
# #### Question 1.4: When can the "anonymized" dataset protect individuals' privacy, and in what situations can it not? (4pt)

# %% [markdown]
# *Write your response here*

# %% [markdown]
# ## Part 2 – Your Digital Footprint
#
# You will explore privacy risks using **your own real-world data**. Many platforms allow you to download an archive of the personal information they store about you. This section examines what can be inferred from that data and how platform design affects privacy-utility tradeoffs.
#
# You may use any platform that allows data export—examples include:
#
# * Instagram (“Download Your Information”)
# * Facebook (“Download Your Information”)
# * TikTok (“Download Your Data”)
# * Twitter/X (“Request Data”)
# * Reddit (“Request Data”)
# * Google (“Takeout”)
#
#
# ### Question 2.1: Download your data archive from one platform of your choice. (4 pt)
#
# Describe:
# * What categories of information the platform stores about you
# * Which data types were surprising, expected, or unclear
#
# Alternatively, if you were unable to download your data describe the experience.

# %% [markdown]
# *Write your response here*

# %% [markdown]
# ## Part 3
#
# Canvas allows instructors to view “access reports” for each student. These access reports contain information about what content each student has viewed, which course files each student has downloaded, etc.
# ![Screen Shot 2022-11-02 at 3.16.22 PM.png](data:image/png;base64,...)
# Instructors can also view "quiz logs," which provide detailed information about students' behavior while taking quizzes.
# ![Screen Shot 2022-11-03 at 7.30.04 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Question 3.1: Do you think Canvas’ access reports and quiz logs provide an appropriate balance between utility for instructors and privacy for students? Why or why not? (4 pts)
